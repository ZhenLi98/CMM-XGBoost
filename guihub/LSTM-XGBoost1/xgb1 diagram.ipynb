# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as style
from matplotlib import colors

# %%
df=pd.read_csv('diagram.csv')
df.head()
# Out:
#       TRUE       fit  prediction
# 0 -0.00602 -0.007870         NaN
# 1 -0.01652 -0.015766         NaN
# 2 -0.00888 -0.006864         NaN
# 3 -0.00642 -0.005306         NaN
# 4 -0.00565 -0.004828         NaN

# %%
x=df['TRUE']
y=df['fit']
z=df['prediction']

# %%
plt.figure(figsize=(50, 25))
plt.rcParams.update({'font.size': 30})
plt.plot(range(len(x)), x, label='true', lineWidth=5)
plt.plot(range(len(y)), y, label='fit', lineWidth=5)
plt.plot(range(len(z)), z, label='prediction', lineWidth=5)
plt.ylabel('U/m')
plt.xlabel('Time')
plt.legend()
plt.axvline(730, -1, 1,color="red")#竖线
plt.show()
# Out:
# <ipython-input-4-3310173fce7b>:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(range(len(x)), x, label='true', lineWidth=5)
# <ipython-input-4-3310173fce7b>:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(range(len(y)), y, label='fit', lineWidth=5)
# <ipython-input-4-3310173fce7b>:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(range(len(z)), z, label='prediction', lineWidth=5)
