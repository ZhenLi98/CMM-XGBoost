# %%
#导入包
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import glob
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#导入数据
df=pd.read_csv('xgb1.csv')
df.head()
# Out:
#    Unnamed: 0      XGB1     HEZJ
# 0           0  0.009951  0.01015
# 1           1  0.009332  0.00853
# 2           2  0.014389  0.01433
# 3           3  0.008817  0.01048
# 4           4  0.009517  0.00988

# %%
x=df['HEZJ']
y=df['XGB1']

# %%
rmse = mean_squared_error(x, y)**0.5
mae = mean_absolute_error(x, y)
mae
# Out:
# 0.0025578569506849312
